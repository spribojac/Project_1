# %% [markdown]
# ## Processing the CSV files for 2015-2020:
#
# ### For 2015-2019 files this process will be followed
#
# 1. The code begins by importing the specific dependencies for the code.
#
# 2. Specifying the file path to the datasets and reads the CSV files
#
# 3. For each CSV file, the following will be completed:
#
#         - Extract the year from the file name (becomes index for merged file)
#
#         - Define a dictionary to map column names to the desired names: "Country", "Happiness Score", "GDP per Capita",
#                            "Social Support", "Life Expectancy/Health", "Freedom", "Trust (government corruption)",
#                            "Generosity".
#
#         - Re-orders to the desired columns for the new dataframe and saves it
#
# 4. Save the processed DataFrame to a separate CSV file for the current year

# %%
# Import the dependencies
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# The path to CSV files
file_paths = ["2015.csv", "2016.csv", "2017.csv", "2018.csv", "2019.csv"]

# %%
# Initialize an empty dictionary to store DataFrames so they can be called later
dfs_by_year = {}

# Loop through the file paths for 2015-2019 and process each file separately
for file_path in file_paths:
    
    # Extract the year from the file name
    year = os.path.splitext(os.path.basename(file_path))[0]
    
    # Read the CSV file
    df = pd.read_csv(file_path, thousands=',', decimal='.')

    # Determine the column name for the "Country" column
    country_column = None
    if 'Country' in df.columns:
        country_column = 'Country'
    elif 'Country or region' in df.columns:
        country_column = 'Country or region'

    if country_column:
        
        # Define a dictionary to map column names to the desired names
        df.rename(columns={
            "Country or region": "Country",
            "Country name": "Country",
            "Happiness.Score": "Happiness Score",
            "Ladder score": "Happiness Score",
            "Score": "Happiness Score",
            "Economy..GDP.per.Capita.": "GDP per Capita",
            "Economy (GDP per Capita)": "GDP per Capita",
            "Logged GDP per capita": "GDP per Capita",
            "GDP per capita": "GDP per Capita",
            "Family": "Social Support",
            "Social support": "Social Support",
            "Explained by: GDP per capita": "GDP per Capita",
            "Health..Life.Expectancy.": "Life Expectancy/Health",
            "Health (Life Expectancy)": "Life Expectancy/Health",
            "Healthy life expectancy": "Life Expectancy/Health",
            "Freedom to make life choices": "Freedom",
            "Trust..Government.Corruption.": "Trust (government corruption)",
            "Trust (Government Corruption)": "Trust (government corruption)",
            "Perceptions of corruption": "Trust (government corruption)",
            "Explained by: Generosity": "Generosity"
        }, inplace=True)

        # Specify order of columns to ensure they are the same across all sheets
        desired_columns = ["Country", "Happiness Score", "GDP per Capita", 
                           "Social Support", "Life Expectancy/Health", "Freedom", "Trust (government corruption)", 
                           "Generosity"]

        df = df[desired_columns]
        
        # Store the DataFrame in the dictionary with the year as the key
        dfs_by_year[year] = df

        # Save the processed DataFrame to a separate CSV file for the current year
        output_file = f"output/{year}_data.csv"
        df.to_csv(output_file, index=False)

# %% [markdown]
# ### For 2020 a new script was needed as columns to be dropped and renamed to merge correctly
#
# 1. The code begins by importing the specific dependencies for the code.
#
# 2. Specifying the file path to the 2020 dataset and reads the CSV file
# 3. Extract the year from the file name
# 4. Read CSV file
# 5. Drop unwanted columns: "Standard error of ladder score",
#     "upperwhisker",
#     "lowerwhisker",
#     "Logged GDP per capita",
#     "Social support",
#     "Healthy life expectancy",
#     "Freedom to make life choices",
#     "Generosity",
#     "Perceptions of corruption",
#     "Ladder score in Dystopia",
#     "Dystopia + residual",
#     "Regional indicator"
#
# 5. Rename the remaining columns as needed: "Country", "Happiness Score", "GDP per Capita",
#                            "Social Support", "Life Expectancy/Health", "Freedom", "Trust (government corruption)",
#                            "Generosity".
#
# 6. Select the desired columns in the specified order
#
# 7. Save the processed DataFrame to a separate CSV file

# %%
# 2020 needs columns dropped to rename and merge correctly
# Define the file path to CSV file
file_path = "2020.csv"

# Extract the year from the file name
year = os.path.splitext(os.path.basename(file_path))[0]

# Read CSV file
df = pd.read_csv(file_path, thousands=',', decimal='.')

# Drop unwanted columns
columns_to_drop = [
    "Standard error of ladder score",
    "upperwhisker",
    "lowerwhisker",
    "Logged GDP per capita",
    "Social support",
    "Healthy life expectancy",
    "Freedom to make life choices",
    "Generosity",
    "Perceptions of corruption",
    "Ladder score in Dystopia",
    "Dystopia + residual",
    "Regional indicator"
]

df.drop(columns=columns_to_drop, inplace=True)

# Rename the remaining columns
df.rename(columns={
    "Country name": "Country",
    "Ladder score": "Happiness Score",
    "Explained by: Log GDP per capita": "GDP per Capita",
    "Explained by: Social support": "Social Support",
    "Explained by: Healthy life expectancy": "Life Expectancy/Health",
    "Explained by: Freedom to make life choices": "Freedom",
    "Explained by: Perceptions of corruption": "Trust (government corruption)",
    "Explained by: Generosity": "Generosity"
}, inplace=True)

# Select the desired columns in the specified order
desired_columns = ["Country", "Happiness Score", "GDP per Capita", 
                           "Social Support", "Life Expectancy/Health", "Freedom", "Trust (government corruption)", 
                           "Generosity"]

df = df[desired_columns]

# Save the processed DataFrame to a separate CSV file for the current year
output_file = f"output/{year}_data.csv"
df.to_csv(output_file, index=False)

# Create a df for 2020
df_2020 = pd.DataFrame(df)
df_2020
# Out:
#                       Country  Happiness Score  GDP per Capita  \
# 0                     Finland           7.8087        1.285190
# 1                     Denmark           7.6456        1.326949
# 2                 Switzerland           7.5599        1.390774
# 3                     Iceland           7.5045        1.326502
# 4                      Norway           7.4880        1.424207
# ..                        ...              ...             ...
# 148  Central African Republic           3.4759        0.041072
# 149                    Rwanda           3.3123        0.343243
# 150                  Zimbabwe           3.2992        0.425564
# 151               South Sudan           2.8166        0.289083
# 152               Afghanistan           2.5669        0.300706
#
#      Social Support  Life Expectancy/Health   Freedom  \
# 0          1.499526                0.961271  0.662317
# 1          1.503449                0.979333  0.665040
# ...

# %%
# Summary statistics for 2020
summary_2020 = df_2020.describe()
df_2020.describe()
# Out:
#        Happiness Score  GDP per Capita  Social Support  \
# count        153.00000      153.000000      153.000000
# mean           5.47324        0.868771        1.155607
# std            1.11227        0.372416        0.286866
# min            2.56690        0.000000        0.000000
# 25%            4.72410        0.575862        0.986718
# 50%            5.51500        0.918549        1.203987
# 75%            6.22850        1.169229        1.387139
# max            7.80870        1.536676        1.547567
#
#        Life Expectancy/Health     Freedom  Trust (government corruption)  \
# count              153.000000  153.000000                     153.000000
# mean                 0.692869    0.463583                       0.130718
# std                  0.254094    0.141172                       0.113097
# min                  0.000000    0.000000                       0.000000
# 25%                  0.495443    0.381457                       0.055805
# ...

# %%
# Access an individual DataFrame by its year
year = "2015"  
df_2015 = dfs_by_year[year]
df_2015
# Out:
#          Country  Happiness Score  GDP per Capita  Social Support  \
# 0    Switzerland            7.587         1.39651         1.34951
# 1        Iceland            7.561         1.30232         1.40223
# 2        Denmark            7.527         1.32548         1.36058
# 3         Norway            7.522         1.45900         1.33095
# 4         Canada            7.427         1.32629         1.32261
# ..           ...              ...             ...             ...
# 153       Rwanda            3.465         0.22208         0.77370
# 154        Benin            3.340         0.28665         0.35386
# 155        Syria            3.006         0.66320         0.47489
# 156      Burundi            2.905         0.01530         0.41587
# 157         Togo            2.839         0.20868         0.13995
#
#      Life Expectancy/Health  Freedom  Trust (government corruption)  \
# 0                   0.94143  0.66557                        0.41978
# ...

# %%
# Collect 2015 summary statistics
summary_2015 = df_2015.describe()
df_2015.describe()
# Out:
#        Happiness Score  GDP per Capita  Social Support  \
# count       158.000000      158.000000      158.000000
# mean          5.375734        0.846137        0.991046
# std           1.145010        0.403121        0.272369
# min           2.839000        0.000000        0.000000
# 25%           4.526000        0.545808        0.856823
# 50%           5.232500        0.910245        1.029510
# 75%           6.243750        1.158448        1.214405
# max           7.587000        1.690420        1.402230
#
#        Life Expectancy/Health     Freedom  Trust (government corruption)  \
# count              158.000000  158.000000                     158.000000
# mean                 0.630259    0.428615                       0.143422
# std                  0.247078    0.150693                       0.120034
# min                  0.000000    0.000000                       0.000000
# 25%                  0.439185    0.328330                       0.061675
# ...

# %%
# Access an individual DataFrame by its year
year = "2016" 
df_2016 = dfs_by_year[year]
df_2016
# Out:
#          Country  Happiness Score  GDP per Capita  Social Support  \
# 0        Denmark            7.526         1.44178         1.16374
# 1    Switzerland            7.509         1.52733         1.14524
# 2        Iceland            7.501         1.42666         1.18326
# 3         Norway            7.498         1.57744         1.12690
# 4        Finland            7.413         1.40598         1.13464
# ..           ...              ...             ...             ...
# 152        Benin            3.484         0.39499         0.10419
# 153  Afghanistan            3.360         0.38227         0.11037
# 154         Togo            3.303         0.28123         0.00000
# 155        Syria            3.069         0.74719         0.14866
# 156      Burundi            2.905         0.06831         0.23442
#
#      Life Expectancy/Health  Freedom  Trust (government corruption)  \
# 0                   0.79504  0.57941                        0.44453
# ...

# %%
# Collect 2016 summary statistics
summary_2016 = df_2016.describe()
df_2016.describe()
# Out:
#        Happiness Score  GDP per Capita  Social Support  \
# count       157.000000      157.000000      157.000000
# mean          5.382185        0.953880        0.793621
# std           1.141674        0.412595        0.266706
# min           2.905000        0.000000        0.000000
# 25%           4.404000        0.670240        0.641840
# 50%           5.314000        1.027800        0.841420
# 75%           6.269000        1.279640        1.021520
# max           7.526000        1.824270        1.183260
#
#        Life Expectancy/Health     Freedom  Trust (government corruption)  \
# count              157.000000  157.000000                     157.000000
# mean                 0.557619    0.370994                       0.137624
# std                  0.229349    0.145507                       0.111038
# min                  0.000000    0.000000                       0.000000
# 25%                  0.382910    0.257480                       0.061260
# ...

# %%
# Access an individual DataFrame by its year
year = "2017"
df_2017 = dfs_by_year[year]
df_2017
# Out:
#                       Country  Happiness Score  GDP per Capita  \
# 0                      Norway            7.537        1.616463
# 1                     Denmark            7.522        1.482383
# 2                     Iceland            7.504        1.480633
# 3                 Switzerland            7.494        1.564980
# 4                     Finland            7.469        1.443572
# ..                        ...              ...             ...
# 150                    Rwanda            3.471        0.368746
# 151                     Syria            3.462        0.777153
# 152                  Tanzania            3.349        0.511136
# 153                   Burundi            2.905        0.091623
# 154  Central African Republic            2.693        0.000000
#
#      Social Support  Life Expectancy/Health   Freedom  \
# 0          1.533524                0.796667  0.635423
# 1          1.551122                0.792566  0.626007
# ...

# %%
# Collect 2017 summary statistics
summary_2017 = df_2017.describe()
df_2017.describe()
# Out:
#        Happiness Score  GDP per Capita  Social Support  \
# count       155.000000      155.000000      155.000000
# mean          5.354019        0.984718        1.188898
# std           1.131230        0.420793        0.287263
# min           2.693000        0.000000        0.000000
# 25%           4.505500        0.663371        1.042635
# 50%           5.279000        1.064578        1.253918
# 75%           6.101500        1.318027        1.414316
# max           7.537000        1.870766        1.610574
#
#        Life Expectancy/Health     Freedom  Trust (government corruption)  \
# count              155.000000  155.000000                     155.000000
# mean                 0.551341    0.408786                       0.123120
# std                  0.237073    0.149997                       0.101661
# min                  0.000000    0.000000                       0.000000
# 25%                  0.369866    0.303677                       0.057271
# ...

# %%
# Access an individual DataFrame by its year
year = "2018"
df_2018 = dfs_by_year[year]
df_2018
# Out:
#                       Country  Happiness Score  GDP per Capita  \
# 0                     Finland            7.632           1.305
# 1                      Norway            7.594           1.456
# 2                     Denmark            7.555           1.351
# 3                     Iceland            7.495           1.343
# 4                 Switzerland            7.487           1.420
# ..                        ...              ...             ...
# 151                     Yemen            3.355           0.442
# 152                  Tanzania            3.303           0.455
# 153               South Sudan            3.254           0.337
# 154  Central African Republic            3.083           0.024
# 155                   Burundi            2.905           0.091
#
#      Social Support  Life Expectancy/Health  Freedom  \
# 0             1.592                   0.874    0.681
# 1             1.582                   0.861    0.686
# ...

# %%
# Collect 2018 summary statistics
summary_2018 = df_2018.describe()
df_2018.describe()
# Out:
#        Happiness Score  GDP per Capita  Social Support  \
# count       156.000000      156.000000      156.000000
# mean          5.375917        0.891449        1.213237
# std           1.119506        0.391921        0.302372
# min           2.905000        0.000000        0.000000
# 25%           4.453750        0.616250        1.066750
# 50%           5.378000        0.949500        1.255000
# 75%           6.168500        1.197750        1.463000
# max           7.632000        2.096000        1.644000
#
#        Life Expectancy/Health     Freedom  Trust (government corruption)  \
# count              156.000000  156.000000                     155.000000
# mean                 0.597346    0.454506                       0.112000
# std                  0.247579    0.162424                       0.096492
# min                  0.000000    0.000000                       0.000000
# 25%                  0.422250    0.356000                       0.051000
# ...

# %%
# Access an individual DataFrame by its year
year = "2019"
df_2019 = dfs_by_year[year]
df_2019
# Out:
#                       Country  Happiness Score  GDP per Capita  \
# 0                     Finland            7.769           1.340
# 1                     Denmark            7.600           1.383
# 2                      Norway            7.554           1.488
# 3                     Iceland            7.494           1.380
# 4                 Netherlands            7.488           1.396
# ..                        ...              ...             ...
# 151                    Rwanda            3.334           0.359
# 152                  Tanzania            3.231           0.476
# 153               Afghanistan            3.203           0.350
# 154  Central African Republic            3.083           0.026
# 155               South Sudan            2.853           0.306
#
#      Social Support  Life Expectancy/Health  Freedom  \
# 0             1.587                   0.986    0.596
# 1             1.573                   0.996    0.592
# ...

# %%
# Collect 2019 summary statistics
summary_2019 = df_2019.describe()
df_2019.describe()
# Out:
#        Happiness Score  GDP per Capita  Social Support  \
# count       156.000000      156.000000      156.000000
# mean          5.407096        0.905147        1.208814
# std           1.113120        0.398389        0.299191
# min           2.853000        0.000000        0.000000
# 25%           4.544500        0.602750        1.055750
# 50%           5.379500        0.960000        1.271500
# 75%           6.184500        1.232500        1.452500
# max           7.769000        1.684000        1.624000
#
#        Life Expectancy/Health     Freedom  Trust (government corruption)  \
# count              156.000000  156.000000                     156.000000
# mean                 0.725244    0.392571                       0.110603
# std                  0.242124    0.143289                       0.094538
# min                  0.000000    0.000000                       0.000000
# 25%                  0.547750    0.308000                       0.047000
# ...

# %%
# Create DataFrames for each year
dataframes = {
    '2015': df_2015,
    '2016': df_2016,
    '2017': df_2017,
    '2018': df_2018,
    '2019': df_2019,
    '2020': df_2020
}

# Concatenate DataFrames into a single DataFrame and add the 'Year' column
df = pd.concat([df.assign(Year=year) for year, df in dataframes.items()], ignore_index=True)

# Calculate the mean values for each variable over the years
mean_data = df.groupby(['Year']).mean()

# Reset the index for plotting
mean_data = mean_data.reset_index()

# Melt the DataFrame for easier plotting
mean_data_melted = pd.melt(mean_data, id_vars=['Year'], var_name='Variable', value_name='Mean Value')
# Out:
# C:\Users\sophi\AppData\Local\Temp\ipykernel_7024\3919298159.py:15: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_data = df.groupby(['Year']).mean()

# %%
# Create a combined line plot for the other variables with labels
plt.figure(figsize=(12, 6))
other_variable_data = mean_data_melted[mean_data_melted['Variable'] != 'Happiness Score']
sns.lineplot(data=other_variable_data, x='Year', y='Mean Value', hue='Variable', marker='o')
plt.title('Mean Change in Happiness Score Over the Years')
plt.xlabel('Year')
plt.ylabel('Mean Value')
plt.title('Mean Change in Variables Over the Years')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Create a line plot for Happiness Score with labels
plt.figure(figsize=(12, 6))
happiness_score_data = mean_data_melted[mean_data_melted['Variable'] == 'Happiness Score']
sns.lineplot(data=happiness_score_data, x='Year', y='Mean Value', marker='o', label='Happiness Score')

# Add labels to each point
for x, y in zip(happiness_score_data['Year'], happiness_score_data['Mean Value']):
    plt.text(x, y, f'{y:.2f}', ha='right', va='bottom')

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
# Looking at the confidence intervals
# Calculate the mean values and standard deviations for each variable over the years
std_data = df.groupby(['Year']).std()

# Reset the index for plotting
std_data = std_data.reset_index()

# Melt the DataFrames for easier plotting
std_data_melted = pd.melt(std_data, id_vars=['Year'], var_name='Variable', value_name='Standard Deviation')

# Create line plots for each variable with confidence intervals on separate graphs
variables = mean_data_melted['Variable'].unique()

for variable in variables:
    plt.figure(figsize=(12, 6))
    variable_data = mean_data_melted[mean_data_melted['Variable'] == variable]
    
    # Calculate confidence intervals for each data point
    confidence_intervals = 1.96 * (std_data_melted[std_data_melted['Variable'] == variable]['Standard Deviation'] / np.sqrt(len(dataframes)))
    
    # Plot the line
    sns.lineplot(data=variable_data, x='Year', y='Mean Value', marker='o', label=variable)
    
    # Plot confidence intervals as error bars
    plt.errorbar(
        x=variable_data['Year'], 
        y=variable_data['Mean Value'], 
        yerr=confidence_intervals,
        linestyle='None',
        capsize=3,
        label='Confidence Intervals'
    )

    plt.xlabel('Year')
    plt.ylabel('Mean Value')
    plt.title(f'Mean Change in {variable} Over the Years')
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    
     # Define the filename based on the variable name (replace "/" with "_")
    filename = f'mean_change_{variable.replace("/", "_")}.png'
    
    # Save the figure as a separate image with the correct filename
    plt.savefig(filename)
    
plt.show()
# Out:
# C:\Users\sophi\AppData\Local\Temp\ipykernel_7024\4108488570.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   std_data = df.groupby(['Year']).std()

# %% [markdown]
# ## Yearly Analysis
# The maximum happiness score observed in each year is close to 7.8, indicating that there are countries with relatively high happiness scores in each year.
#
# ### Happiness Score
# Looking at the line graph above the mean Happiness Score has remained relatively stable over the years, with slight fluctuations, mainly in the years 2019-2020 where a very small increase in the Happiness score can be seen
#
#
# ### GDP per capita
# The mean GDP per capita has shown a consistent positive trend over the years, indicating an improvement in economic well-being.
# The standard deviation suggests that there is significant variation in GDP per capita among countries, especially in recent years.
#
# ### Social Support
#
# Social support, on average, has seen a gradual increase over the years, implying an improvement in the perceived availability of social networks.
# The standard deviation shows some variability in social support among countries, especially in the earlier years.
#
# ### Life Expectancy/Health:
#
# Mean life expectancy and health have remained relatively stable over the years, with slight fluctuations.
# The standard deviation indicates that there is variability in life expectancy among countries, but it hasn't changed significantly over time.
#
# ### Freedom:
#
# Mean freedom has seen minor fluctuations but has remained relatively constant over the years.
# The standard deviation suggests that there is some variability in the perceived freedom to make life choices among countries.
#
# ### Trust (Government Corruption):
#
# Mean trust in government corruption has remained relatively stable over the years, with some variations.
# The standard deviation indicates that there is variability in trust levels among countries, especially in recent years.
#
# ### Generosity:
#
# The mean generosity score has shown some fluctuations but has not exhibited a clear upward or downward trend.
# The standard deviation suggests that there is variability in generosity among countries, particularly in recent years.
#
# Overall, these observations suggest that while some variables have shown consistent improvements (e.g., GDP per capita and social support), others have remained relatively stable (e.g., happiness score and life expectancy/health). Variability among countries in these variables is evident, indicating that different nations have experienced different levels of well-being and societal conditions over the years.
